# %% [raw]
# This is a startup Panda Project with Python
#
# Weather Data Analysis

# %%
WE FIRST HAVE TO IMPORT THE PYTHON LIBRARY PANDA 
WHICH WILL BE USED TO SOLVE THE PROBLEMS AT HAND

# %%
import pandas as pd

# %%
IMPORT THE CSV FILE THAT CONTAINS THE DATA

# %%
data = pd.read_csv(r"C:\Users\YHAW FYNN\Python_Projects\Project1.csv")

# %%
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# .HEAD()
# It shows the first N rows in the data(by default, N=5).

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# .SHAPE
# It shows the total no of rows and columns in a dataframe. Its done without a ()

# %%
data.shape
# Out:
# (8784, 8)

# %% [markdown]
# .INDEX
# It shows the index of the dataframe

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %% [markdown]
# .COLUMN
# It shows the names of each column

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %% [markdown]
# .DTYPES
# It shows the data types of each column

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %% [markdown]
# .UNIQUE()
# It can be applied to a single column only to show its unique content values

# %%
data['Temp_C'].unique()
# Out:
# array([ -1.8,  -1.5,  -1.4,  -1.3,  -1. ,  -0.5,  -0.2,   0.2,   0.8,
#          1.8,   2.6,   3. ,   3.8,   3.1,   3.2,   4. ,   4.4,   5.3,
#          5.2,   4.6,   3.9,   3.7,   2.9,   2.3,   2. ,   1.9,   1.5,
#          2.2,   1.7,   1.1,   0. ,  -0.7,  -2.1,  -4.1,  -4.8,  -5.6,
#         -5.8,  -7. ,  -7.4,  -9. ,  -9.7, -10.5, -11.3, -12.6, -12.9,
#        -13.3, -14. , -14.8, -15. , -15.3, -14.9, -15.1, -15.8, -16.3,
#        -16.9, -17.3, -17. , -17.1, -17.5, -17.9, -18.1, -18.5, -18.6,
#        -18.2, -17.8, -16.8, -15.2, -14.2, -13.7, -12.4, -10.2,  -9.4,
#         -8.9,  -8.4,  -7.8,  -7.6,  -9.5,  -9.6,  -8.8,  -7.5,  -5.4,
#         -5. ,  -8.2,  -7.1,  -6.1,  -6.6,  -6. ,  -4.7,  -4.4,  -5.1,
#         -4.3,  -6.7,  -9.2,  -9.8,  -9.9, -10. , -10.6, -11.8, -12. ,
#        -14.4, -12.3, -12.5, -11.7, -11.9, -11.2, -11.5, -11.6,  -9.3,
#         -8.7,  -8.5,  -8.1,  -6.9,  -6.4,  -5.7,  -5.5,  -3.7,  -3.6,
# ...

# %% [markdown]
# .NUNIQUE()
# It shows the total no. of unique values in a columns. It can be applied to a single or all the columns.

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %% [markdown]
# .COUNT()
# It shows the total no. of non-null in each column

# %%
data['Weather'].count()
# Out:
# 8784

# %%
.VALUE_COUNTS
It shows the unique values with their count.

# %%
data['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# Q1. FIND ALL THE UNIQUE 'WIND SPEED' VALUES IN THE DATA

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %% [markdown]
# BELOW ARE SOME QUESTIONS CONCERNING THE DATA AT HAND THAT NEEDS TO BE ANSWERED

# %%
data['Wind Speed_km/h'].nunique()
# Out:
# 34

# %%
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %% [markdown]
# Q2. FIND THE NUMBER OF TIMES WHEN THE 'WEATHER IS EXACTLY CLEAR'

# %%
# VALUE_COUNTS 
# data.Weather.value_counts()
data['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
# FILTERING
data[data.Weather  == 'Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
# GROUPBY
data.groupby('Weather').get_group('Clear')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# Q3. FIND THE NO. OF TIMES WHEN THE "WIND SPEED WAS AT EXACTLY 4KM/H".

# %%
# GROUPBY
data.groupby('Wind Speed_km/h').get_group(4)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
# FILTERING
data[data['Wind Speed_km/h'] == 4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
# VALUE_COUNT
data['Wind Speed_km/h'].value_counts()
# Out:
# Wind Speed_km/h
# 9     830
# 11    791
# 13    735
# 15    719
# 7     677
# 17    666
# 19    616
# 6     609
# 20    496
# 4     474
# 22    439
# 24    374
# 0     309
# 26    242
# 28    205
# 30    161
# 32    139
# 33     85
# 35     53
# 37     45
# 39     24
# 41     22
# 44     14
# 43     13
# 48     13
# 46     11
# 52      7
# 57      5
# 50      4
# 2       2
# 83      1
# 70      1
# 63      1
# 54      1
# Name: count, dtype: int64

# %% [markdown]
# Q4. FIND OUT ALL THE NULL VALUES IN THE DATASET

# %%
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# Q5. RENAME THE COLUMN NAMED 'WEATHER' or 'TEMP_C' OF THE DATAFRAME TO 'WEATHER CONDITION' or 'TEMPERATURE_C'

# %%
#data.rename(columns = {'Weather' : 'Weather Condition'}, inplace = True)
#data.rename(columns = {'Temp_C' : 'Temperature_C'}, inplace = True)
data.head()
# Out:
#        Date/Time  Temperature_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00           -1.8              -3.9         86                4
# 1  1/1/2012 1:00           -1.8              -3.7         87                4
# 2  1/1/2012 2:00           -1.8              -3.4         89                7
# 3  1/1/2012 3:00           -1.5              -3.2         88                6
# 4  1/1/2012 4:00           -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather Condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# Q6. WHAT IS THE MEAN 'VISIBILITY'?

# %%
data.head(2)
# Out:
#        Date/Time  Temperature_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00           -1.8              -3.9         86                4
# 1  1/1/2012 1:00           -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data.Visibility_km.mean()
# Out:
# 27.664446721311478

# %% [markdown]
# Q7. WHAT IS THE STANDARD DEVIATION OF 'PRESSURE' IN THIS DATA?

# %%
data.head(2)
# Out:
#        Date/Time  Temperature_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00           -1.8              -3.9         86                4
# 1  1/1/2012 1:00           -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data.Press_kPa.std()
# Out:
# 0.8440047459486474

# %% [markdown]
# Q8. WHAT IS THE VARIANCE OF 'RELATIVE HUMIDITY' IN THIS DATA?

# %%
data.head(2)
# Out:
#        Date/Time  Temperature_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00           -1.8              -3.9         86                4
# 1  1/1/2012 1:00           -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %% [markdown]
# Q9. FIND ALL INSTANCES WHEN 'SNOW' WAS RECORDED

# %%
data.head(2)
# Out:
#        Date/Time  Temperature_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00           -1.8              -3.9         86                4
# 1  1/1/2012 1:00           -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
# VALUE_COUNTS
data['Weather Condition'].value_counts()
# Out:
# Weather Condition
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
# GROUPBY
data.groupby('Weather Condition').get_group('Snow')
# Out:
#              Date/Time  Temperature_C  Dew Point Temp_C  Rel Hum_%  \
# 55       1/3/2012 7:00          -14.0             -19.5         63
# 84      1/4/2012 12:00          -13.7             -21.7         51
# 86      1/4/2012 14:00          -11.3             -19.0         53
# 87      1/4/2012 15:00          -10.2             -16.3         61
# 88      1/4/2012 16:00           -9.4             -15.5         61
# ...                ...            ...               ...        ...
# 8779  12/31/2012 19:00            0.1              -2.7         81
# 8780  12/31/2012 20:00            0.2              -2.4         83
# 8781  12/31/2012 21:00           -0.5              -1.5         93
# 8782  12/31/2012 22:00           -0.2              -1.8         89
# 8783  12/31/2012 23:00            0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Condition
# 55                 19           25.0     100.95              Snow
# ...

# %%
# FILTERING
data[data['Weather Condition'] == 'Snow']
# Out:
#              Date/Time  Temperature_C  Dew Point Temp_C  Rel Hum_%  \
# 55       1/3/2012 7:00          -14.0             -19.5         63
# 84      1/4/2012 12:00          -13.7             -21.7         51
# 86      1/4/2012 14:00          -11.3             -19.0         53
# 87      1/4/2012 15:00          -10.2             -16.3         61
# 88      1/4/2012 16:00           -9.4             -15.5         61
# ...                ...            ...               ...        ...
# 8779  12/31/2012 19:00            0.1              -2.7         81
# 8780  12/31/2012 20:00            0.2              -2.4         83
# 8781  12/31/2012 21:00           -0.5              -1.5         93
# 8782  12/31/2012 22:00           -0.2              -1.8         89
# 8783  12/31/2012 23:00            0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Condition
# 55                 19           25.0     100.95              Snow
# ...

# %%
# STR.CONTAINS
data[data['Weather Condition'].str.contains('Snow')].head(100)
# Out:
#            Date/Time  Temperature_C  Dew Point Temp_C  Rel Hum_%  \
# 41    1/2/2012 17:00           -2.1              -9.5         57
# 44    1/2/2012 20:00           -5.6             -13.4         54
# 45    1/2/2012 21:00           -5.8             -12.8         58
# 47    1/2/2012 23:00           -7.4             -14.1         59
# 48     1/3/2012 0:00           -9.0             -16.0         57
# ..               ...            ...               ...        ...
# 304  1/13/2012 16:00           -3.7              -6.0         84
# 305  1/13/2012 17:00           -2.9              -4.8         87
# 306  1/13/2012 18:00           -1.7              -3.3         89
# 307  1/13/2012 19:00           -2.5              -4.5         86
# 308  1/13/2012 20:00           -3.2              -5.1         87
#
#      Wind Speed_km/h  Visibility_km  Press_kPa Weather Condition
# 41                22           25.0      99.66      Snow Showers
# ...

# %% [markdown]
# Q10. FIND ALL INSTANCES WHEN 'WINDSPEED IS ABOVE 24' AND 'VISIBILITY IS 25'

# %%
data.head(2)
# Out:
#        Date/Time  Temperature_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00           -1.8              -3.9         86                4
# 1  1/1/2012 1:00           -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data[(data['Wind Speed_km/h'] > 24) & (data['Visibility_km'] == 25)]
# Out:
#              Date/Time  Temperature_C  Dew Point Temp_C  Rel Hum_%  \
# 23      1/1/2012 23:00            5.3               2.0         79
# 24       1/2/2012 0:00            5.2               1.5         77
# 25       1/2/2012 1:00            4.6               0.0         72
# 26       1/2/2012 2:00            3.9              -0.9         71
# 27       1/2/2012 3:00            3.7              -1.5         69
# ...                ...            ...               ...        ...
# 8705  12/28/2012 17:00           -8.6             -12.0         76
# 8753  12/30/2012 17:00          -12.1             -15.8         74
# 8755  12/30/2012 19:00          -13.4             -16.5         77
# 8759  12/30/2012 23:00          -12.1             -15.1         78
# 8760   12/31/2012 0:00          -11.1             -14.4         77
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Condition
# 23                 30           25.0      99.31            Cloudy
# ...

# %% [markdown]
# Q11. WHAT IS THE MINIMUM VALUE OF EACH COLUMN AGAINST EACH 'WEATHER CONDITION'

# %%
data.groupby('Weather Condition').min().head()
# Out:
#                                Date/Time  Temperature_C  Dew Point Temp_C  \
# Weather Condition
# Clear                     1/11/2012 1:00          -23.3             -28.5
# Cloudy                    1/1/2012 17:00          -21.4             -26.8
# Drizzle                  1/23/2012 21:00            1.1              -0.2
# Drizzle,Fog              1/23/2012 20:00            0.0              -1.6
# Drizzle,Ice Pellets,Fog  12/17/2012 9:00            0.4              -0.7
#
#                          Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa
# Weather Condition
# Clear                           20                0           11.3      99.52
# Cloudy                          18                0           11.3      98.39
# Drizzle                         74                0            6.4      97.84
# Drizzle,Fog                     85                0            1.0      98.65
# Drizzle,Ice Pellets,Fog         92               20            4.0     100.79

# %% [markdown]
# Q12. SHOW ALL RECORDS WHERE WEATHER IS FOG

# %%
data.groupby('Weather Condition').get_group('Fog')
# Out:
#              Date/Time  Temperature_C  Dew Point Temp_C  Rel Hum_%  \
# 0        1/1/2012 0:00           -1.8              -3.9         86
# 1        1/1/2012 1:00           -1.8              -3.7         87
# 4        1/1/2012 4:00           -1.5              -3.3         88
# 5        1/1/2012 5:00           -1.4              -3.3         87
# 6        1/1/2012 6:00           -1.5              -3.1         89
# ...                ...            ...               ...        ...
# 8716   12/29/2012 4:00          -16.0             -17.2         90
# 8717   12/29/2012 5:00          -14.8             -15.9         91
# 8718   12/29/2012 6:00          -13.8             -15.3         88
# 8719   12/29/2012 7:00          -14.8             -16.4         88
# 8722  12/29/2012 10:00          -12.0             -13.3         90
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Condition
# 0                   4            8.0     101.24               Fog
# ...

# %% [markdown]
# Q13. FIND ALL INSTANCES WHEN 'WEATHER IS CLEAR' OR 'VISIBILITY IS ABOVE 40'.

# %%
data.head(2)
# Out:
#        Date/Time  Temperature_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00           -1.8              -3.9         86                4
# 1  1/1/2012 1:00           -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data[(data['Weather Condition'] == 'Clear') | (data['Visibility_km'] > 40)]
# Out:
#              Date/Time  Temperature_C  Dew Point Temp_C  Rel Hum_%  \
# 67      1/3/2012 19:00          -16.9             -24.8         50
# 106     1/5/2012 10:00           -6.0             -10.0         73
# 107     1/5/2012 11:00           -5.6             -10.2         70
# 108     1/5/2012 12:00           -4.7              -9.6         69
# 109     1/5/2012 13:00           -4.4              -9.7         66
# ...                ...            ...               ...        ...
# 8749  12/30/2012 13:00          -12.4             -16.2         73
# 8750  12/30/2012 14:00          -11.8             -16.1         70
# 8751  12/30/2012 15:00          -11.3             -15.6         70
# 8752  12/30/2012 16:00          -11.4             -15.5         72
# 8756  12/30/2012 20:00          -13.8             -16.5         80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Condition
# 67                 24           25.0     101.74             Clear
# ...

# %% [markdown]
# Q14. FIND ALL INSTANCES WHEN:
#     A. 'WEATHER IS CLEAR' AND 'RELATIVE HUMIDITY IS GREATER THAN 50'
#
#     or
#
#     B. 'VISIBILITY IS ABOVE 40'

# %%
data.head(2)
# Out:
#        Date/Time  Temperature_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00           -1.8              -3.9         86                4
# 1  1/1/2012 1:00           -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data[(data['Weather Condition'] == 'Clear') & (data['Rel Hum_%'] > 50) | (data['Visibility_km'] > 40)]
# Out:
#              Date/Time  Temperature_C  Dew Point Temp_C  Rel Hum_%  \
# 106     1/5/2012 10:00           -6.0             -10.0         73
# 107     1/5/2012 11:00           -5.6             -10.2         70
# 108     1/5/2012 12:00           -4.7              -9.6         69
# 109     1/5/2012 13:00           -4.4              -9.7         66
# 110     1/5/2012 14:00           -5.1             -10.7         65
# ...                ...            ...               ...        ...
# 8749  12/30/2012 13:00          -12.4             -16.2         73
# 8750  12/30/2012 14:00          -11.8             -16.1         70
# 8751  12/30/2012 15:00          -11.3             -15.6         70
# 8752  12/30/2012 16:00          -11.4             -15.5         72
# 8756  12/30/2012 20:00          -13.8             -16.5         80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather Condition
# 106                17           48.3     100.45      Mainly Clear
# ...
